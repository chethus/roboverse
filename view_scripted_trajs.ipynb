# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def view_traj(dataset_path, traj_ind=0):
    dataset = np.load(dataset_path, allow_pickle=True)
    traj_observations = dataset[traj_ind]['observations']
    for obs in traj_observations:
        plt.imshow(obs['image'])
        plt.show()

# %%
import numpy as np
a = np.load('/media/3tb/chet/robo_exp/d4rl/conic_cup_Widow250GraspEasyTrain-conic_cup-v0_5K_noise_0.1_2022-04-18T12-25-01_5000_d4rl.npy', allow_pickle=True)

# %%
dataset_path='/media/3tb/chet/robo_exp/easy_train/conic_cup_Widow250GraspEasyTrain-conic_cup-v0_5K_noise_0.1_2022-04-18T12-25-01_5000.npy'
view_traj(dataset_path)
